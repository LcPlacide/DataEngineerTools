# %% [markdown]
# # Scrapping des infos utiles sur les animés

# %%
# Importation des packages nécessaires
import scrapy
import pandas as pd

# %%
# Création du projet Scrappy nommé animescrawler
# !scrapy startproject animescrawler
# Out:
# Error: scrapy.cfg already exists in /home/lcplacide/Documents/DataEngineerTools/6Evaluation/Projet/animescrawler

# %%
# Création de la spider myanimelist pour scrapper myanimelist.net
# !cd animescrawler && scrapy genspider myanimelist myanimelist.net
# Out:
# Created spider 'myanimelist' using template 'basic' in module:
#   {spiders_module.__name__}.{module}

# %% [markdown]
# ## 1. Récupérer le menu de navigation horizontal de la page https://myanimelist.net/anime.php (#,A,B,....Z)

# %%
scrapy shell 'https://myanimelist.net/anime.php'
response.css("#horiznav_nav").css("a::text").extract()
In [18]: response.css("#horiznav_nav").css("a::attr(href)").extract()
Out[18]: 
['https://myanimelist.net/anime.php?em=0&ed=0&ey=0&o=2&c%5B0%5D=a&c%5B1%5D=d&cv=1&w=0&sd=24&sm=11&sy=2020',
 'https://myanimelist.net/anime.php?o=9&c%5B0%5D=a&c%5B1%5D=d&cv=2&w=1',
 'https://myanimelist.net/anime.php?letter=.',
 'https://myanimelist.net/anime.php?letter=A',
 'https://myanimelist.net/anime.php?letter=B',
 'https://myanimelist.net/anime.php?letter=C',
 'https://myanimelist.net/anime.php?letter=D',
 'https://myanimelist.net/anime.php?letter=E',
 'https://myanimelist.net/anime.php?letter=F',
 'https://myanimelist.net/anime.php?letter=G',
 'https://myanimelist.net/anime.php?letter=H',
 'https://myanimelist.net/anime.php?letter=I',
 'https://myanimelist.net/anime.php?letter=J',
 'https://myanimelist.net/anime.php?letter=K',
 'https://myanimelist.net/anime.php?letter=L',
 'https://myanimelist.net/anime.php?letter=M',
 'https://myanimelist.net/anime.php?letter=N',
 'https://myanimelist.net/anime.php?letter=O',
 'https://myanimelist.net/anime.php?letter=P',
 'https://myanimelist.net/anime.php?letter=Q',
 'https://myanimelist.net/anime.php?letter=R',
 'https://myanimelist.net/anime.php?letter=S',
 'https://myanimelist.net/anime.php?letter=T',
 'https://myanimelist.net/anime.php?letter=U',
 'https://myanimelist.net/anime.php?letter=V',
 'https://myanimelist.net/anime.php?letter=W',
 'https://myanimelist.net/anime.php?letter=X',
 'https://myanimelist.net/anime.php?letter=Y',
 'https://myanimelist.net/anime.php?letter=Z']

# %% [markdown]
# ## 2. Récupération des pages associées à chaque élément du menu de navigation

# %%
scrapy shell 'https://myanimelist.net/anime.php?letter=A'
nb_page_A = int(response.css(".normal_header").css("a::text").extract()[-1])
last_link_page_A = response.urljoin(response.css(".normal_header").css("a::attr(href)").extract()[-1]) 
link_common_part_A = last_link_page_A.replace("show="+str((nb_page_A-1)*50),"show=")
all_link_page_A = [ link_common_part_A+str(i) for i in range(0,nb_page_A*50,50)]
Out[26]: 
['https://myanimelist.net/anime.php?letter=A&show=0',
 'https://myanimelist.net/anime.php?letter=A&show=50',
 'https://myanimelist.net/anime.php?letter=A&show=100',
 'https://myanimelist.net/anime.php?letter=A&show=150',
 'https://myanimelist.net/anime.php?letter=A&show=200',
 'https://myanimelist.net/anime.php?letter=A&show=250',
 'https://myanimelist.net/anime.php?letter=A&show=300',
 'https://myanimelist.net/anime.php?letter=A&show=350',
 'https://myanimelist.net/anime.php?letter=A&show=400',
 'https://myanimelist.net/anime.php?letter=A&show=450',
 'https://myanimelist.net/anime.php?letter=A&show=500',
 'https://myanimelist.net/anime.php?letter=A&show=550',
 'https://myanimelist.net/anime.php?letter=A&show=600',
 'https://myanimelist.net/anime.php?letter=A&show=650',
 'https://myanimelist.net/anime.php?letter=A&show=700',
 'https://myanimelist.net/anime.php?letter=A&show=750',
 'https://myanimelist.net/anime.php?letter=A&show=800',
 'https://myanimelist.net/anime.php?letter=A&show=850',
 'https://myanimelist.net/anime.php?letter=A&show=900']

# %% [markdown]
# ## 3. Récupération des pages spécifiques à chaque animé

# %%
scrapy shell 'https://myanimelist.net/anime.php?letter=A&show=0'
anime_link_A1 = set(response.css(".hoverinfo_trigger").css("a::attr(href)").extract())
Out[18]: 
{'https://myanimelist.net/anime/1003/Aa_Megami-sama_TV_Specials',
 'https://myanimelist.net/anime/10737/A-Channel___A-Channel',
 'https://myanimelist.net/anime/11339/A-Channel_smile',
 'https://myanimelist.net/anime/1295/A-Ko_The_Versus',
 'https://myanimelist.net/anime/1349/AD_Police_TV',
 'https://myanimelist.net/anime/17501/Abe_George_Kattobi_Seishun_Ki__Shibuya_Honky_Tonk',
 'https://myanimelist.net/anime/2198/Aa_Megami-sama__Sorezore_no_Tsubasa_Specials',
 'https://myanimelist.net/anime/22831/Abarenbou_Rikishi_Matsutarou',
 'https://myanimelist.net/anime/25397/Absolute_Duo',
 'https://myanimelist.net/anime/2884/Aachi_wa_Ssipak',
 'https://myanimelist.net/anime/29750/AAA_de_Ikou__Yuuna___Akiko',
 'https://myanimelist.net/anime/29902/A_Play',
 'https://myanimelist.net/anime/30214/A_Smart_Experiment',
 'https://myanimelist.net/anime/303/Aa_Megami-sama__Chichaitte_Koto_wa_Benri_da_ne',
 'https://myanimelist.net/anime/304/Aa_Megami-sama_Movie',
 'https://myanimelist.net/anime/305/Abashiri_Ikka',
 'https://myanimelist.net/anime/306/Abenobashi_Mahou☆Shoutengai',
 'https://myanimelist.net/anime/3090/Aa_Megami-sama__Tatakau_Tsubasa',
 'https://myanimelist.net/anime/320/A_Kite',
 'https://myanimelist.net/anime/32484/A-Size_Classmate',
 'https://myanimelist.net/anime/33337/ACCA__13-ku_Kansatsu-ka',
 'https://myanimelist.net/anime/3463/ALICE',
 'https://myanimelist.net/anime/35285/A-Channel__Nabe_wo_Tabeyou',
 'https://myanimelist.net/anime/36039/AICO__Incarnation',
 'https://myanimelist.net/anime/36182/Abstract_feat_Alkama',
 'https://myanimelist.net/anime/37180/A_Tang_Qi_Yu',
 'https://myanimelist.net/anime/37452/A_Woman_in_a_Fashion_Building',
 'https://myanimelist.net/anime/38701/Aa___ii',
 'https://myanimelist.net/anime/38712/A_Log_Day_of_Timbre',
 'https://myanimelist.net/anime/39057/A_New_Journey',
 'https://myanimelist.net/anime/39086/A_Christmas_Song',
 'https://myanimelist.net/anime/39184/A3_Season_Spring___Summer',
 'https://myanimelist.net/anime/39997/Ab-rah',
 'https://myanimelist.net/anime/40272/A3_Season_Autumn___Winter',
 'https://myanimelist.net/anime/40628/A_Brightening_Life',
 'https://myanimelist.net/anime/41319/A_song_for_You_You_You',
 'https://myanimelist.net/anime/41449/A_Sea_Doesnt_Tell_Much',
 'https://myanimelist.net/anime/42481/A_Day_Before_Us',
 'https://myanimelist.net/anime/44040/Abciee_Shuugyou_Nikki',
 'https://myanimelist.net/anime/49/Aa_Megami-sama',
 'https://myanimelist.net/anime/4934/AF',
 'https://myanimelist.net/anime/50/Aa_Megami-sama_TV',
 'https://myanimelist.net/anime/5447/A-Girl',
 'https://myanimelist.net/anime/5877/Abunai_Sisters__Koko___Mika',
 'https://myanimelist.net/anime/6094/A_Piece_of_Phantasmagoria',
 'https://myanimelist.net/anime/8216/Aa_Harimanada',
 'https://myanimelist.net/anime/880/Aa_Megami-sama__Sorezore_no_Tsubasa',
 'https://myanimelist.net/anime/9433/A-jangcom',
 'https://myanimelist.net/anime/9611/Aa_Megami-sama_2011',
 'https://myanimelist.net/anime/9776/A-Channel'}

# %% [markdown]
# ## 4. Récupération des infos utiles de chaque animé
# - Main title
# - Alternative title
# - Score
# - Synopsis
# - Ranked
# - Popularity
# - Genres
# - Producers
# - Licensors
# - Studios
# - Type
# - Related animes
# - Duration
# - Rating

# %%
scrapy shell 'https://myanimelist.net/anime/1003/Aa_Megami-sama_TV_Specials'
main_title = response.css("h1").css("strong::text").extract_first()
                          
Out[26]: 'Aa! Megami-sama! (TV) Specials'

# %%
scrapy shell 'https://myanimelist.net/anime/1003/Aa_Megami-sama_TV_Specials'
other_titles= response.xpath("//div[@style='width: 225px']/div[@class='spaceit_pad']/text()").extract()
other_titles = [elt.strip() for elt in alternative_titles if elt.strip()!='']

Out[32]: ['Ah! My Goddess! Specials, Aa! Megami-sama! Episodes 12.5, 25 and 26, Oh! My Goddess Specials', 'ああっ女神さまっ']

# %%
scrapy shell 'https://myanimelist.net/anime/1003/Aa_Megami-sama_TV_Specials'
score = response.css(".score-label::text").extract_first()

Out[34]: '7.54'

# %%
scrapy shell 'https://myanimelist.net/anime/1003/Aa_Megami-sama_TV_Specials'
synopsis = response.xpath("//p[@itemprop='description']").css("::text").extract()

Out[36]: 'Due to the recent events that happened on the last episodes of the season, the Goddess have some stability problems with their body systems. The always adult looking Urd becomes a little girl and has a fateful encounter with a boy, whereas little Skuld becomes an adult and wants to experiment adulthood together with Keiichi.'

# %%
scrapy shell 'https://myanimelist.net/anime/1003/Aa_Megami-sama_TV_Specials'
ranked = response.xpath("//div[@class='di-ib ml12 pl20 pt8']/span[@class='numbers ranked']/strong/text()").extract_first()
popularity = response.xpath("//div[@class='di-ib ml12 pl20 pt8']/span[@class='numbers popularity']/strong/text()").extract_first()

Out[39]: ('#1447', '#3253')

# %%
scrapy shell 'https://myanimelist.net/anime/1003/Aa_Megami-sama_TV_Specials'
genres = response.xpath("//span[@itemprop='genre']/text()").extract()

Out[42]: ['Magic', 'Comedy', 'Romance', 'Supernatural', 'Seinen']

# %%
scrapy shell 'https://myanimelist.net/anime/1003/Aa_Megami-sama_TV_Specials'
producers_licensors_studios = response.xpath("//div[@style='width: 225px']").xpath("//a[contains(@href,'/anime/producer')]/text()").extract()

Out[45]: ['Bandai Visual', 'AIC', 'Media Blasters', 'NYAV Post']

# %%
scrapy shell 'https://myanimelist.net/anime/1003/Aa_Megami-sama_TV_Specials'
table= response.xpath("//table[@class='anime_detail_related_anime']/tr")
related_anime= dict([(tr.css("td::text").extract_first(),tr.css("td a::text").extract()) for tr in table])

Out[126]: {'Adaptation': ['Aa! Megami-sama!'], 'Parent story': ['Aa! Megami-sama! (TV)']}

# %%
scrapy shell 'https://myanimelist.net/anime/1003/Aa_Megami-sama_TV_Specials'
border = response.xpath("//div[@style='width: 225px']")
divs= [div for div in border.css("div") if div.css("span::text").extract_first() in ["Duration:","Rating:","Type:"]]
border_infos=dict([(div.css("span::text").extract_first(),div.css("::text").extract()[-1])for div in divs])

Out[4]: 
{'Type:': 'Special',
 'Duration:': '\n  24 min. per ep.\n  ',
 'Rating:': '\n  PG-13 - Teens 13 or older\n  '}

# %% [markdown]
# ## Implémentation de la spider

# %%
# !cd animescrawler/animescrawler/spiders && scrapy runspider myanimelist.py
# Out:
# 'duration': datetime.time(0, 12),
#  'genres': ['Music', 'Slice of Life', 'School', 'Shoujo'],
#  'main_title': 'Aikatsu on Parade! (ONA)',
#  'other_titles': {'Aikatsu on Parade!: Dream Story', 'アイカツオンパレード!'},
#  'popularity': 10693,
#  'producers': {'Bandai Namco Pictures'},
#  'ranked': 6322,
#  'rating': 'PG - Children',
#  'related_anime': {'Alternative setting': ['Aikatsu!', 'Aikatsu Stars!'],
#                    'Parent story': ['Aikatsu on Parade!'],
#                    'Prequel': ['Aikatsu Friends!: Kagayaki no Jewel']},
#  'score': 6.4,
#  'synopsis': '"Dream School Grand Prix" to decide the No.1 idol school among '
#              'five schools representing the Aikatsu world will be held! In '
#              'this competition where top idols representing each school '
#              "compete on stage, Dream Academy's new idol Noel Otoshiro is "
#              "selected as one of them?! For each idol's dream, a new story "
#              'starts running into the shining future! (Source: Crunchyroll)'}
# 2020-12-13 21:07:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/39078/Aikatsu_Friends__Kagayaki_no_Jewel> (referer: https://myanimelist.net/anime.php?letter=A&show=150)
# 2020-12-13 21:07:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/anime/39078/Aikatsu_Friends__Kagayaki_no_Jewel>
# {'Type': 'TV',
#  'duration': datetime.time(0, 24),
#  'genres': ['Music', 'Slice of Life', 'School', 'Shoujo'],
#  'main_title': 'Aikatsu Friends!: Kagayaki no Jewel',
#  'other_titles': {'アイカツフレンズ！~かがやきのジュエル~'},
#  'popularity': 7415,
#  'producers': {'Bandai Namco Pictures'},
#  'ranked': 4031,
#  'rating': 'PG - Children',
#  'related_anime': {'Prequel': ['Aikatsu Friends!'],
#                    'Sequel': ['Aikatsu on Parade!',
#                               'Aikatsu on Parade! (ONA)']},
#  'score': 6.89,
#  'synopsis': 'The story takes place two years after Aikatsu Friends! with Aine '
#              'Yuuki now in high school. One day she has an encounter with the '
#              'mysterious idol Hibiki Tenshou who wears the shining Jeweling '
#              'Dress.'}
# 2020-12-13 21:07:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/13053/Aimai_Elegy> (referer: https://myanimelist.net/anime.php?letter=A&show=150)
# 2020-12-13 21:07:56 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/anime/13053/Aimai_Elegy>
# {'Type': 'Music',
#  'duration': datetime.time(0, 3),
#  'genres': ['Music'],
#  'main_title': 'Aimai Elegy',
#  'other_titles': {'愛迷エレジー', 'Love-lost Elegy'},
#  'popularity': 7935,
#  'producers': [],
#  'ranked': 5641,
#  'rating': 'PG-13 - Teens 13 or older',
#  'related_anime': {},
#  'score': 6.54,
#  'synopsis': 'Music video by DECO*27. A girl struggles with her fear of a '
#              'relationship, feeling drowned by the possibilities of the '
#              "future. But she's not the only one drowning..."}
# 2020-12-13 21:07:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/32806/Aikatsu__Nerawareta_Mahou_no_Aikatsu_Card> (referer: https://myanimelist.net/anime.php?letter=A&show=150)
# 2020-12-13 21:07:59 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/anime/32806/Aikatsu__Nerawareta_Mahou_no_Aikatsu_Card>
# {'Type': 'Movie',
#  'duration': datetime.time(0, 27),
#  'genres': ['Music', 'Slice of Life', 'School', 'Shoujo'],
#  'main_title': 'Aikatsu!: Nerawareta Mahou no Aikatsu! Card',
#  'other_titles': {'Aikatsu! Aiming for the Magical Aikatsu Card',
#                   'アイカツ！〜ねらわれた魔法のアイカツ！カード〜'},
#  'popularity': 8122,
#  'producers': {'Bandai Namco Pictures'},
#  'ranked': 2588,
#  'rating': 'PG - Children',
#  'related_anime': {'Other': ['Aikatsu Stars! Movie'], 'Prequel': ['Aikatsu!']},
#  'score': 7.24,
#  'synopsis': 'Short anime screened alongside Aikatsu Stars! Movie. The film '
#              'and the short will mark the first time the franchise is '
#              'screening a double feature. (Source: ANN)'}
# 2020-12-13 21:08:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/39085/Aikagi_The_Animation> (referer: https://myanimelist.net/anime.php?letter=A&show=150)
# 2020-12-13 21:08:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/anime/39085/Aikagi_The_Animation>
# {'Type': 'OVA',
#  'duration': datetime.time(0, 26),
#  'genres': ['Hentai'],
#  'main_title': 'Aikagi The Animation',
#  'other_titles': {'アイカギ The Animation'},
#  'popularity': 6009,
#  'producers': {'Pink Pineapple'},
#  'ranked': None,
#  'rating': 'Rx - Hentai',
#  'related_anime': {'Other': ['Aibeya The Animation']},
#  'score': 7.08,
#  'synopsis': 'It was the last winter of his school life and with entrance '
#              "exams and graduation edging closer, Nozomu didn't know what to "
#              "do. He was told to become independent, but he couldn't find a "
#              'suitable place to live by himself. His childhood friend Shiori '
#              "couldn't stand watching him in his current state and suggested "
#              "that he live with her. While he thought that it wouldn't really "
#              'make him independent, his parents readily agreed to the idea. '
#              'Before he knew it, they were living together under the same '
#              "roof. Their cohabitation was only to last one month. Since it's "
#              "only for a short period and she's his childhood friend, he "
#              'thought that nothing wrong will happen. However, living together '
#              "with Shiori revealed to him aside which he hadn't seen before, "
#              'and he began to see her as a woman. Where will their '
#              'relationship end up now that he had begun to have feelings for '
#              'her? (Source: vndb)'}
# 2020-12-13 21:08:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/31908/Ai_think_so> (referer: https://myanimelist.net/anime.php?letter=A&show=150)
# 2020-12-13 21:08:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/anime/31908/Ai_think_so>
# {'Type': 'Music',
#  'duration': datetime.time(0, 4),
#  'genres': ['Music'],
#  'main_title': 'Ai think so,',
#  'other_titles': {'Love (I) think so,', '愛 think so,'},
#  'popularity': 11074,
#  'producers': {'U/M/A/A Inc.'},
#  'ranked': 9356,
#  'rating': 'G - All Ages',
#  'related_anime': {},
#  'score': 5.56,
#  'synopsis': 'Music video for DECO*27\'s song "Ai think so,".'}
# 2020-12-13 21:08:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/39629/Aihime_Megohime> (referer: https://myanimelist.net/anime.php?letter=A&show=150)
# 2020-12-13 21:08:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/anime/39629/Aihime_Megohime>
# {'Type': 'ONA',
#  'duration': datetime.time(0, 10),
#  'genres': ['Fantasy', 'Historical'],
#  'main_title': 'Aihime Megohime',
#  'other_titles': {'愛姫MEGOHIME'},
#  'popularity': 13152,
#  'producers': {'Gaina'},
#  'ranked': 13010,
#  'rating': 'PG-13 - Teens 13 or older',
#  'related_anime': {},
#  'score': None,
#  'synopsis': None}
# 2020-12-13 21:08:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/656/Air_in_Summer> (referer: https://myanimelist.net/anime.php?letter=A&show=150)
# 2020-12-13 21:08:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/anime/656/Air_in_Summer>
# {'Type': 'Special',
#  'duration': datetime.time(0, 24),
#  'genres': ['Romance', 'Supernatural', 'Comedy', 'Historical', 'Drama'],
#  'main_title': 'Air in Summer',
#  'other_titles': {'AIR イン サマー',
#                   'Air in Summer',
#                   'Air in Summer Special, Air Summer Special'},
#  'popularity': 2599,
#  'producers': {'ADV Films',
#                'Funimation',
#                'Kyoto Animation',
#                'Pony Canyon',
#                'TBS'},
#  'ranked': 2161,
#  'rating': 'PG-13 - Teens 13 or older',
#  'related_anime': {'Parent story': ['Air']},
#  'score': 7.34,
#  'synopsis': 'An extension of the summer-arc in the Air TV-series, showing '
#              "more of what happened during Kanna's, Ryuya's and Uraha's "
#              "journey to find Kanna's mother."}
# 2020-12-13 21:08:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/1895/Ai_wa_Kagi_no_Kazu_dake_Fuuzoku_Mansion> (referer: https://myanimelist.net/anime.php?letter=A&show=150)
# 2020-12-13 21:08:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/anime/1895/Ai_wa_Kagi_no_Kazu_dake_Fuuzoku_Mansion>
# {'Type': 'OVA',
#  'duration': datetime.time(0, 30),
#  'genres': ['Hentai'],
#  'main_title': 'Ai wa Kagi no Kazu dake... Fuuzoku Mansion',
#  'other_titles': {'Ai ha Kagi no Kazu dake... Fuuzoku Mansion, Love is the '
#                   'Number of Keys',
#                   'Love is the Number of Keys',
#                   '愛は鍵の数だけ… 風俗マンション'},
#  'popularity': 7218,
#  'producers': {'Milky Animation Label', 'NuTech Digital'},
#  'ranked': None,
#  'rating': 'Rx - Hentai',
#  'related_anime': {},
#  'score': 6.28,
#  'synopsis': 'Jyun is on his own for the first time as his father has gone '
#              'overseas for a new job. He stays behind because of schooling and '
#              'moves into an appartment complex as assistant manager only to '
#              'discover the place is a sex service appartment.'}
# 2020-12-13 21:08:17 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/37204/Aikatsu_Friends> (referer: https://myanimelist.net/anime.php?letter=A&show=150)
# 2020-12-13 21:08:17 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/anime/37204/Aikatsu_Friends>
# {'Type': 'TV',
#  'duration': datetime.time(0, 24),
#  'genres': ['Music', 'Slice of Life', 'School', 'Shoujo'],
#  'main_title': 'Aikatsu Friends!',
#  'other_titles': {'アイカツフレンズ！'},
#  'popularity': 5163,
#  'producers': {'Dentsu', 'Echoes', 'TV Tokyo', 'Bandai Namco Pictures'},
#  'ranked': 3125,
#  'rating': 'PG - Children',
#  'related_anime': {'Alternative setting': ['Aikatsu!', 'Aikatsu Stars!'],
#                    'Sequel': ['Aikatsu Friends!: Kagayaki no Jewel']},
#  'score': 7.11,
#  'synopsis': "Aine Yuuki, who is a regular student at Star Harmony Academy's "
#              'normal division, meets Mio Minato from the idol division, who '
#              "invites her to join Aikatsu to fulfill Aine's goal to make "
#              'friends. She also befriends Maika Chōno and Ema Hinata who are '
#              'also idols. Aine and Mio form a pair to become best friends to '
#              'become the bright "Diamond Friends". Karen Kamishiro and Mirai '
#              'Asuku are categorized as "Diamond Friends" and are in the '
#              'Diamond Class! (Source: Wikipedia)'}
# 2020-12-13 21:08:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/22819/Aikatsu_Movie> (referer: https://myanimelist.net/anime.php?letter=A&show=150)
# 2020-12-13 21:08:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/anime/22819/Aikatsu_Movie>
# {'Type': 'Movie',
#  'duration': datetime.time(1, 28),
#  'genres': ['Slice of Life', 'Music', 'School', 'Shoujo'],
#  'main_title': 'Aikatsu! Movie',
#  'other_titles': {'Gekijouban Aikatsu! Idol Katsudou!, Aikatsu! Idol Katsudou! '
#                   'Movie',
#                   '劇場版 アイカツ！アイドルカツドウ！'},
#  'popularity': 5928,
#  'producers': {'Sunrise'},
#  'ranked': 1902,
#  'rating': 'PG - Children',
#  'related_anime': {'Parent story': ['Aikatsu!'],
#                    'Side story': ['Aikatsu!: Dai Starmiya Ichigo Matsuri '
#                                   'Zenyasai!!']},
#  'score': 7.4,
#  'synopsis': 'The story of the anime revolves around Ichigo, who was just a '
#              'normal middle school student until she suddenly got involved in '
#              "the world of idols. The film will center on Aikatsu!'s greatest "
#              '"Super Live" concert yet, the Dai Star Miya Ichigo Matsuri. '
#              'Ichigo prepares for the concert with press conferences, '
#              'last-minute lessons, and more. (Source: ANN)'}
# 2020-12-13 21:08:22 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/4718/AIKa__Special_Trial> (referer: https://myanimelist.net/anime.php?letter=A&show=150)
# 2020-12-13 21:08:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/anime/4718/AIKa__Special_Trial>
# {'Type': 'Special',
#  'duration': datetime.time(0, 10),
#  'genres': ['Ecchi'],
#  'main_title': 'AIKa: Special Trial',
#  'other_titles': {'AIKa Special TRIAL',
#                   'Agent Aika Special, Agent Aika Episode 4.5, Agent Aika '
#                   'Moving Out'},
#  'popularity': 5879,
#  'producers': {'Bandai Entertainment', 'Studio Fantasia'},
#  'ranked': 9010,
#  'rating': 'R+ - Mild Nudity',
#  'related_anime': {'Side story': ['AIKa']},
#  'score': 5.69,
#  'synopsis': 'A bonus episode about Aika and company moving to a new office.'}
# 2020-12-13 21:08:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/32804/Ainone> (referer: https://myanimelist.net/anime.php?letter=A&show=150)
# 2020-12-13 21:08:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/anime/32804/Ainone>
# {'Type': 'Music',
#  'duration': datetime.time(0, 1),
#  'genres': ['Music', 'Drama'],
#  'main_title': 'Ainone',
#  'other_titles': {'Yen Town Band - Ai no Ne', 'アイノネ'},
#  'popularity': 11321,
#  'producers': {'Universal Music Japan'},
#  'ranked': 10606,
#  'rating': 'PG-13 - Teens 13 or older',
#  'related_anime': {},
#  'score': 4.7,
#  'synopsis': 'A music video for the song "Ainone" by Yen Town Band.'}
# 2020-12-13 21:08:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/6709/Ai_Yori_Aoshi__Yumegatari> (referer: https://myanimelist.net/anime.php?letter=A&show=150)
# 2020-12-13 21:08:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/anime/6709/Ai_Yori_Aoshi__Yumegatari>
# {'Type': 'Special',
#  'duration': datetime.time(0, 4),
#  'genres': ['Comedy', 'Harem', 'Romance', 'Slice of Life'],
#  'main_title': 'Ai Yori Aoshi: Yumegatari',
#  'other_titles': {'Ai Yori Aoshi: Dream Story,',
#                   'Ai Yori Aoshi: Speaking of Dreams',
#                   '藍より青し 夢語り'},
#  'popularity': 4927,
#  'producers': {'J.C.Staff', 'Funimation'},
#  'ranked': 4428,
#  'rating': 'PG-13 - Teens 13 or older',
#  'related_anime': {'Parent story': ['Ai Yori Aoshi']},
#  'score': 6.79,
#  'synopsis': 'Kaoru and the girls have a picnic in Spring and talk about their '
#              'dreams for the future.'}
# 2020-12-13 21:08:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/32150/Ai_to_Shi> (referer: https://myanimelist.net/anime.php?letter=A&show=150)
# 2020-12-13 21:08:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/anime/32150/Ai_to_Shi>
# {'Type': 'Special',
#  'duration': datetime.time(0, 1),
#  'genres': ['Action'],
#  'main_title': 'Ai to Shi',
#  'other_titles': {'愛と死'},
#  'popularity': 12404,
#  'producers': [],
#  'ranked': 9357,
#  'rating': 'G - All Ages',
#  'related_anime': {},
#  'score': 5.56,
#  'synopsis': "Director Wataru Uekusa's work for NHK's Educational Television "
#              'channel. The Techne Tri corner teaches watchers certain features '
#              'of animation, this video was a part of his rotoscoping lesson.'}
# 2020-12-13 21:08:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/32717/Aikatsu_Stars> (referer: https://myanimelist.net/anime.php?letter=A&show=150)
# 2020-12-13 21:08:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/anime/32717/Aikatsu_Stars>
# {'Type': 'TV',
#  'duration': datetime.time(0, 24),
#  'genres': ['Music', 'School', 'Shoujo', 'Slice of Life'],
#  'main_title': 'Aikatsu Stars!',
#  'other_titles': {'アイカツスターズ！'},
#  'popularity': 4173,
#  'producers': {'Echoes', 'TV Tokyo', 'Bandai Namco Pictures'},
#  'ranked': 1453,
#  'rating': 'PG - Children',
#  'related_anime': {'Alternative setting': ['Aikatsu!', 'Aikatsu Friends!'],
#                    'Side story': ['Aikatsu Stars! Movie']},
#  'score': 7.54,
#  'synopsis': 'Yume Nijino has been accepted into Four Stars academy, home of '
#              'the beautiful and talented S4 idol group. She and the other '
#              'newcomers are determined to discover their talent, with a choice '
#              'of specializing in beauty, singing, dancing, or drama. A tough '
#              'road lies ahead of them, and they must rely on each other to '
#              'overcome their weaknesses and develop their unique strengths. At '
#              "the first-years' opening performances, Yume performs stellarly "
#              'but faints and is unable to remember being on stage at all. '
#              'Struggling to find her talent, she meets Rola "Laura" Sakuraba '
#              'and the two develop a friendly rivalry, working together to '
#              'learn and improve. Though they have their differences, all the '
#              'students share the same goal: to become the next S4 idol. But '
#              'hard work and determination, along with teamwork, are needed if '
#              'they want to join the elite S4. [Written by MAL Rewrite]'}
# 2020-12-13 21:08:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/38365/Aigan_Kaijuu> (referer: https://myanimelist.net/anime.php?letter=A&show=150)
# 2020-12-13 21:08:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/anime/38365/Aigan_Kaijuu>
# {'Type': 'TV',
#  'duration': datetime.time(0, 3),
#  'genres': ['Action', 'Sci-Fi', 'Comedy', 'Parody', 'Fantasy'],
#  'main_title': 'Aigan Kaijuu',
#  'other_titles': {'愛玩怪獣'},
#  'popularity': 13079,
#  'producers': {'Shimogumi', 'TV Tokyo'},
#  'ranked': 13009,
#  'rating': 'PG-13 - Teens 13 or older',
#  'related_anime': {},
#  'score': None,
#  'synopsis': 'The surreal world view of "scary cute" monsters that rampage '
#              'endlessly. They look and act like toys but being several stories '
#              'tall, the destruction on Japan is devastating.'}
# 2020-12-13 21:08:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/1533/Ai_Tenshi_Densetsu_Wedding_Peach> (referer: https://myanimelist.net/anime.php?letter=A&show=150)
# 2020-12-13 21:08:41 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/anime/1533/Ai_Tenshi_Densetsu_Wedding_Peach>
# {'Type': 'TV',
#  'duration': datetime.time(0, 24),
#  'genres': ['Adventure', 'Magic', 'Comedy', 'Romance', 'Shoujo'],
#  'main_title': 'Ai Tenshi Densetsu Wedding Peach',
#  'other_titles': {'Legend of the Angel of Love - Wedding Peach',
#                   'Wedding Peach',
#                   '愛天使伝説 ウェディングピーチ'},
#  'popularity': 3747,
#  'producers': {'ADV Films', 'Nihon Ad Systems', 'Studio Jack', 'OLM', 'KSS'},
#  'ranked': 4882,
#  'rating': 'G - All Ages',
#  'related_anime': {'Adaptation': ['Wedding Peach'],
#                    'Sequel': ['Ai Tenshi Densetsu Wedding Peach DX'],
#                    'Side story': ['Ai Tenshi Densetsu Wedding Peach Specials']},
#  'score': 6.69,
#  'synopsis': 'There are three known worlds—the human world, the angel world, '
#              'and the devil world. The evil queen Raindevilla yearns to '
#              'destroy the angel world with help or her many devil minions. The '
#              'goddess Aphrodite sends an angel to the human world, Limone, to '
#              'summon three love angels in the form of three school girls, '
#              'Momoko Hanasaki, Yuri Tanima, and Hinagiku Tamano, who together '
#              'become Angel Lilly, Angel Daisy, and Wedding Peach. The three '
#              'girls must fight to overcome the evils of the devils, as well as '
#              'their own lives, and restore peace to the angel world by '
#              'gathering all pieces of the Sacred Four Somethings (or Saint '
#              'Something Four) and defeat the evil queen once and for all. '
#              '(Source: ANN)'}
# 2020-12-13 21:08:42 [scrapy.extensions.logstats] INFO: Crawled 760 pages (at 20 pages/min), scraped 707 items (at 20 items/min)
# ^C
# 2020-12-13 21:08:43 [scrapy.crawler] INFO: Received SIGINT, shutting down gracefully. Send again to force
# 2020-12-13 21:08:43 [scrapy.core.engine] INFO: Closing spider (shutdown)
