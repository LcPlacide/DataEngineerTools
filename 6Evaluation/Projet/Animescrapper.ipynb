# %% [markdown]
# # Scrapping des infos utiles sur les animés

# %%
# Importation des packages nécessaires
import scrapy
import pandas as pd

# %%
# Création du projet Scrappy nommé animescrawler
# !scrapy startproject animescrawler
# Out:
# Error: scrapy.cfg already exists in /home/lcplacide/Documents/DataEngineerTools/6Evaluation/Projet/animescrawler

# %%
# Création de la spider myanimelist pour scrapper myanimelist.net
# !cd animescrawler && scrapy genspider myanimelist myanimelist.net
# Out:
# Created spider 'myanimelist' using template 'basic' in module:
#   {spiders_module.__name__}.{module}

# %% [markdown]
# ## 1. Récupérer le menu de navigation horizontal de la page https://myanimelist.net/anime.php (#,A,B,....Z)

# %%
scrapy shell 'https://myanimelist.net/anime.php'
response.css("#horiznav_nav").css("a::text").extract()
In [18]: response.css("#horiznav_nav").css("a::attr(href)").extract()
Out[18]: 
['https://myanimelist.net/anime.php?em=0&ed=0&ey=0&o=2&c%5B0%5D=a&c%5B1%5D=d&cv=1&w=0&sd=24&sm=11&sy=2020',
 'https://myanimelist.net/anime.php?o=9&c%5B0%5D=a&c%5B1%5D=d&cv=2&w=1',
 'https://myanimelist.net/anime.php?letter=.',
 'https://myanimelist.net/anime.php?letter=A',
 'https://myanimelist.net/anime.php?letter=B',
 'https://myanimelist.net/anime.php?letter=C',
 'https://myanimelist.net/anime.php?letter=D',
 'https://myanimelist.net/anime.php?letter=E',
 'https://myanimelist.net/anime.php?letter=F',
 'https://myanimelist.net/anime.php?letter=G',
 'https://myanimelist.net/anime.php?letter=H',
 'https://myanimelist.net/anime.php?letter=I',
 'https://myanimelist.net/anime.php?letter=J',
 'https://myanimelist.net/anime.php?letter=K',
 'https://myanimelist.net/anime.php?letter=L',
 'https://myanimelist.net/anime.php?letter=M',
 'https://myanimelist.net/anime.php?letter=N',
 'https://myanimelist.net/anime.php?letter=O',
 'https://myanimelist.net/anime.php?letter=P',
 'https://myanimelist.net/anime.php?letter=Q',
 'https://myanimelist.net/anime.php?letter=R',
 'https://myanimelist.net/anime.php?letter=S',
 'https://myanimelist.net/anime.php?letter=T',
 'https://myanimelist.net/anime.php?letter=U',
 'https://myanimelist.net/anime.php?letter=V',
 'https://myanimelist.net/anime.php?letter=W',
 'https://myanimelist.net/anime.php?letter=X',
 'https://myanimelist.net/anime.php?letter=Y',
 'https://myanimelist.net/anime.php?letter=Z']

# %% [markdown]
# ## 2. Récupération des pages associées à chaque élément du menu de navigation

# %%
scrapy shell 'https://myanimelist.net/anime.php?letter=A'
nb_page_A = int(response.css(".normal_header").css("a::text").extract()[-1])
last_link_page_A = response.urljoin(response.css(".normal_header").css("a::attr(href)").extract()[-1]) 
link_common_part_A = last_link_page_A.replace("show="+str((nb_page_A-1)*50),"show=")
all_link_page_A = [ link_common_part_A+str(i) for i in range(0,nb_page_A*50,50)]
Out[26]: 
['https://myanimelist.net/anime.php?letter=A&show=0',
 'https://myanimelist.net/anime.php?letter=A&show=50',
 'https://myanimelist.net/anime.php?letter=A&show=100',
 'https://myanimelist.net/anime.php?letter=A&show=150',
 'https://myanimelist.net/anime.php?letter=A&show=200',
 'https://myanimelist.net/anime.php?letter=A&show=250',
 'https://myanimelist.net/anime.php?letter=A&show=300',
 'https://myanimelist.net/anime.php?letter=A&show=350',
 'https://myanimelist.net/anime.php?letter=A&show=400',
 'https://myanimelist.net/anime.php?letter=A&show=450',
 'https://myanimelist.net/anime.php?letter=A&show=500',
 'https://myanimelist.net/anime.php?letter=A&show=550',
 'https://myanimelist.net/anime.php?letter=A&show=600',
 'https://myanimelist.net/anime.php?letter=A&show=650',
 'https://myanimelist.net/anime.php?letter=A&show=700',
 'https://myanimelist.net/anime.php?letter=A&show=750',
 'https://myanimelist.net/anime.php?letter=A&show=800',
 'https://myanimelist.net/anime.php?letter=A&show=850',
 'https://myanimelist.net/anime.php?letter=A&show=900']

# %% [markdown]
# ## 3. Récupération des pages spécifiques à chaque animé

# %%
scrapy shell 'https://myanimelist.net/anime.php?letter=A&show=0'
anime_link_A1 = set(response.css(".hoverinfo_trigger").css("a::attr(href)").extract())
Out[18]: 
{'https://myanimelist.net/anime/1003/Aa_Megami-sama_TV_Specials',
 'https://myanimelist.net/anime/10737/A-Channel___A-Channel',
 'https://myanimelist.net/anime/11339/A-Channel_smile',
 'https://myanimelist.net/anime/1295/A-Ko_The_Versus',
 'https://myanimelist.net/anime/1349/AD_Police_TV',
 'https://myanimelist.net/anime/17501/Abe_George_Kattobi_Seishun_Ki__Shibuya_Honky_Tonk',
 'https://myanimelist.net/anime/2198/Aa_Megami-sama__Sorezore_no_Tsubasa_Specials',
 'https://myanimelist.net/anime/22831/Abarenbou_Rikishi_Matsutarou',
 'https://myanimelist.net/anime/25397/Absolute_Duo',
 'https://myanimelist.net/anime/2884/Aachi_wa_Ssipak',
 'https://myanimelist.net/anime/29750/AAA_de_Ikou__Yuuna___Akiko',
 'https://myanimelist.net/anime/29902/A_Play',
 'https://myanimelist.net/anime/30214/A_Smart_Experiment',
 'https://myanimelist.net/anime/303/Aa_Megami-sama__Chichaitte_Koto_wa_Benri_da_ne',
 'https://myanimelist.net/anime/304/Aa_Megami-sama_Movie',
 'https://myanimelist.net/anime/305/Abashiri_Ikka',
 'https://myanimelist.net/anime/306/Abenobashi_Mahou☆Shoutengai',
 'https://myanimelist.net/anime/3090/Aa_Megami-sama__Tatakau_Tsubasa',
 'https://myanimelist.net/anime/320/A_Kite',
 'https://myanimelist.net/anime/32484/A-Size_Classmate',
 'https://myanimelist.net/anime/33337/ACCA__13-ku_Kansatsu-ka',
 'https://myanimelist.net/anime/3463/ALICE',
 'https://myanimelist.net/anime/35285/A-Channel__Nabe_wo_Tabeyou',
 'https://myanimelist.net/anime/36039/AICO__Incarnation',
 'https://myanimelist.net/anime/36182/Abstract_feat_Alkama',
 'https://myanimelist.net/anime/37180/A_Tang_Qi_Yu',
 'https://myanimelist.net/anime/37452/A_Woman_in_a_Fashion_Building',
 'https://myanimelist.net/anime/38701/Aa___ii',
 'https://myanimelist.net/anime/38712/A_Log_Day_of_Timbre',
 'https://myanimelist.net/anime/39057/A_New_Journey',
 'https://myanimelist.net/anime/39086/A_Christmas_Song',
 'https://myanimelist.net/anime/39184/A3_Season_Spring___Summer',
 'https://myanimelist.net/anime/39997/Ab-rah',
 'https://myanimelist.net/anime/40272/A3_Season_Autumn___Winter',
 'https://myanimelist.net/anime/40628/A_Brightening_Life',
 'https://myanimelist.net/anime/41319/A_song_for_You_You_You',
 'https://myanimelist.net/anime/41449/A_Sea_Doesnt_Tell_Much',
 'https://myanimelist.net/anime/42481/A_Day_Before_Us',
 'https://myanimelist.net/anime/44040/Abciee_Shuugyou_Nikki',
 'https://myanimelist.net/anime/49/Aa_Megami-sama',
 'https://myanimelist.net/anime/4934/AF',
 'https://myanimelist.net/anime/50/Aa_Megami-sama_TV',
 'https://myanimelist.net/anime/5447/A-Girl',
 'https://myanimelist.net/anime/5877/Abunai_Sisters__Koko___Mika',
 'https://myanimelist.net/anime/6094/A_Piece_of_Phantasmagoria',
 'https://myanimelist.net/anime/8216/Aa_Harimanada',
 'https://myanimelist.net/anime/880/Aa_Megami-sama__Sorezore_no_Tsubasa',
 'https://myanimelist.net/anime/9433/A-jangcom',
 'https://myanimelist.net/anime/9611/Aa_Megami-sama_2011',
 'https://myanimelist.net/anime/9776/A-Channel'}

# %% [markdown]
# ## 4. Récupération des infos utiles de chaque animé
# - Main title
# - Alternative title
# - Score
# - Synopsis
# - Ranked
# - Popularity
# - Genres
# - Producers
# - Licensors
# - Studios
# - Type
# - Related animes
# - Duration
# - Rating

# %%
scrapy shell 'https://myanimelist.net/anime/1003/Aa_Megami-sama_TV_Specials'
main_title = response.css("h1").css("strong::text").extract_first()
                          
Out[26]: 'Aa! Megami-sama! (TV) Specials'

# %%
scrapy shell 'https://myanimelist.net/anime/1003/Aa_Megami-sama_TV_Specials'
alternative_titles = response.xpath("//div[@style='width: 225px']/div[@class='spaceit_pad']/text()").extract()
alternative_titles = [elt.strip() for elt in alternative_titles if elt.strip()!='']

Out[32]: ['Ah! My Goddess! Specials, Aa! Megami-sama! Episodes 12.5, 25 and 26, Oh! My Goddess Specials', 'ああっ女神さまっ']

# %%
scrapy shell 'https://myanimelist.net/anime/1003/Aa_Megami-sama_TV_Specials'
score = response.css(".score-label::text").extract_first()

Out[34]: '7.54'

# %%
scrapy shell 'https://myanimelist.net/anime/1003/Aa_Megami-sama_TV_Specials'
synopsis = response.css("td").css("p::text").extract_first()

Out[36]: 'Due to the recent events that happened on the last episodes of the season, the Goddess have some stability problems with their body systems. The always adult looking Urd becomes a little girl and has a fateful encounter with a boy, whereas little Skuld becomes an adult and wants to experiment adulthood together with Keiichi.'

# %%
scrapy shell 'https://myanimelist.net/anime/1003/Aa_Megami-sama_TV_Specials'
stats_block = response.css(".di-ib").css("strong::text").extract()
ranked, popularity = stats_block[0] , stats_block[1]

Out[39]: ('#1447', '#3253')

# %%
scrapy shell 'https://myanimelist.net/anime/1003/Aa_Megami-sama_TV_Specials'
genres = response.xpath("//span[@itemprop='genre']/text()").extract()

Out[42]: ['Magic', 'Comedy', 'Romance', 'Supernatural', 'Seinen']

# %%
scrapy shell 'https://myanimelist.net/anime/1003/Aa_Megami-sama_TV_Specials'
producers_licensors_studios = response.xpath("//div[@style='width: 225px']").xpath("//a[contains(@href,'/anime/producer')]/text()").extract()

Out[45]: ['Bandai Visual', 'AIC', 'Media Blasters', 'NYAV Post']

# %%
scrapy shell 'https://myanimelist.net/anime/1003/Aa_Megami-sama_TV_Specials'
Type = response.xpath("//div[@style='width: 225px']").xpath('//a[contains(@href,"//myanimelist.net/topanime.php?type=")]/text()').extract_first()

Out[47]: 'Special'

# %%
scrapy shell 'https://myanimelist.net/anime/1003/Aa_Megami-sama_TV_Specials'
table = response.xpath("//table[@class='anime_detail_related_anime']/tr/td").extract()
rowname = response.xpath("//table[@class='anime_detail_related_anime']/tr/td/text()").extract()
name = response.xpath("//table[@class='anime_detail_related_anime']/tr/td/a/text()").extract()

def clean_related_anime_table(table,rowname,name):
    res,l=[None,[]]*len(rowname),rowname+name
    table=pd.Series(table)
    for elt in l:
        n=table.str.contains(">"+elt+"<",regex=False).argmax()
        if elt in name:
            res[n]=res[n]+[elt]
        else:
            res[n]=elt[:len(elt)-1]
    res = dict([(res[i],res[i+1]) for i in range(0,len(res),2)])
    return res
related_anime = clean_related_anime_table(table,rowname,name)

Out[126]: {'Adaptation': ['Aa! Megami-sama!'], 'Parent story': ['Aa! Megami-sama! (TV)']}

# %%
scrapy shell 'https://myanimelist.net/anime/1003/Aa_Megami-sama_TV_Specials'
duration_rating = response.xpath("//div[@style='width: 225px']/div/text()").extract() 
duration_rating = pd.Series([elt.strip() for elt in duration_rating if elt.strip()!='']) 
duration_line = duration_rating.str.contains("hr.|min.|per ep.").argmax() 
rating =  duration_rating.iloc[duration_line+1] 
duration = duration_rating.iloc[duration_line] 

Out[91]: ('24 min. per ep.', 'PG-13 - Teens 13 or older')

# %% [markdown]
# ## Implémentation de la spider

# %%
# !cd animescrawler/animescrawler/spiders && scrapy runspider myanimelist.py
# Out:
# Arimasu!',
#                                   'Keroro Gunsou Movie 3: Tenkuu Daikessen de '
#                                   'Arimasu!',
#                                   'Keroro Gunsou Movie 4: Gekishin Dragon '
#                                   'Warriors de Arimasu!',
#                                   'Keroro Gunsou Movie 5: Tanjou! Kyuukyoku '
#                                   'Keroro, Kiseki no Jikuu-jima, de Arimasu!!'],
#                    'Spin-off': ['Chibi Kero: Kerobouru no Himitsu!?']},
#  'score': '7.72',
#  'synopsis': 'Unsuspecting inhabitants of the planet Earth are going about '
#              'their business, enjoying a bright and particularly beautiful '
#              'sunny day, when a young Japanese boy spots a shiny object '
#              'falling from the sky... Has an alien invasion finally begun?'}
# 2020-12-11 23:39:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/38828/Ketakuma_no_DVD> (referer: https://myanimelist.net/anime.php?letter=K&show=650)
# 2020-12-11 23:39:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/anime/38828/Ketakuma_no_DVD>
# {'Type': 'OVA',
#  'duration_rating': {'duration': '1 min. per ep.', 'rating': 'G - All Ages'},
#  'genres': ['Comedy'],
#  'main_title': 'Ketakuma no DVD',
#  'other_titles': ['Takuma, Ketatamashiku Ugoko Kuma', 'けたくまのDVD'],
#  'producers': [],
#  'ranked_popularity': {'popularity': '16254', 'rank': '14799'},
#  'related_anime': None,
#  'score': 'N/A',
#  'synopsis': "Ketakuma is a popular LINE stamp character. He's featured in the "
#              'gif stamps section and his character won the 2016 LINE Creators '
#              "Stamp Award. Pony Canyon has now teamed up with Ketakuma's "
#              'designer to make a fully animated DVD ripe with comedy skits and '
#              'music videos.  '}
# 2020-12-11 23:39:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/41100/Keshikko> (referer: https://myanimelist.net/anime.php?letter=K&show=650)
# 2020-12-11 23:39:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/anime/41100/Keshikko>
# {'Type': 'ONA',
#  'duration_rating': {'duration': '1 min.', 'rating': 'G - All Ages'},
#  'genres': ['Music', 'Kids'],
#  'main_title': 'Keshikko',
#  'other_titles': ['Keshiko', 'ケシっこ'],
#  'producers': {'Kamio Japan'},
#  'ranked_popularity': {'popularity': '17057', 'rank': '14796'},
#  'related_anime': None,
#  'score': 'N/A',
#  'synopsis': " is Kamio Japan's new character line. Based in a stationary "
#              'world, these are animals that live in erasers (keshigomu).'}
# 2020-12-11 23:39:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/8244/Keshikasu-kun> (referer: https://myanimelist.net/anime.php?letter=K&show=650)
# 2020-12-11 23:39:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/anime/8244/Keshikasu-kun>
# {'Type': 'TV',
#  'duration_rating': {'duration': '1 min. per ep.', 'rating': 'G - All Ages'},
#  'genres': ['Comedy', 'Kids'],
#  'main_title': 'Keshikasu-kun',
#  'other_titles': ['ケシカスくん'],
#  'producers': {'Shogakukan Music & Digital Entertainment'},
#  'ranked_popularity': {'popularity': '13851', 'rank': '14795'},
#  'related_anime': None,
#  'score': 'N/A',
#  'synopsis': 'Keshikasu-kun is an anthropomorphism anime about stationery. The '
#              'main character is the eraser Keshikasu who aims to be an idol of '
#              'the stationary world. He fights against other stationary and '
#              'erases a mechanical pencil or gets crushed by a permanent '
#              'marker.'}
# 2020-12-11 23:39:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/22647/Kero_Kero_Keroppi_no_Sora_Tobu_Yume_no_Fune> (referer: https://myanimelist.net/anime.php?letter=K&show=650)
# 2020-12-11 23:39:39 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/anime/22647/Kero_Kero_Keroppi_no_Sora_Tobu_Yume_no_Fune>
# {'Type': 'OVA',
#  'duration_rating': {'duration': '30 min.', 'rating': 'G - All Ages'},
#  'genres': ['Fantasy', 'Kids'],
#  'main_title': 'Kero Kero Keroppi no Sora Tobu Yume no Fune',
#  'other_titles': ['けろけろけろっぴの空とぶゆめの船'],
#  'producers': {'Sanrio'},
#  'ranked_popularity': {'popularity': '14773', 'rank': '14788'},
#  'related_anime': None,
#  'score': 'N/A',
#  'synopsis': 'Keroppi and friends get special tickets to ride a flying ship at '
#              'night to look at the constellations. Whether they dreamt the '
#              'same dream or encountered it for real is up interpretation.'}
# 2020-12-11 23:39:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/21671/Keroro> (referer: https://myanimelist.net/anime.php?letter=K&show=650)
# 2020-12-11 23:39:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/anime/21671/Keroro>
# {'Type': 'TV',
#  'duration_rating': {'duration': '3 min. per ep.',
#                      'rating': 'PG-13 - Teens 13 or older'},
#  'genres': ['Comedy', 'Sci-Fi', 'Shounen'],
#  'main_title': 'Keroro',
#  'other_titles': ['Keroro Gunsou TV 2, Keroro Gunsou (2014)', 'ケロロ'],
#  'producers': {'Sunrise'},
#  'ranked_popularity': {'popularity': '5650', 'rank': '4184'},
#  'related_anime': {'Adaptation': ['Keroro Gunsou', 'Keroro Gunsou']},
#  'score': '6.86',
#  'synopsis': 'Second TV (flash animated) series of Keroro Gunsou.'}
# 2020-12-11 23:39:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/307/Kerokko_Demetan> (referer: https://myanimelist.net/anime.php?letter=K&show=650)
# 2020-12-11 23:39:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/anime/307/Kerokko_Demetan>
# {'Type': 'TV',
#  'duration_rating': {'duration': '24 min. per ep.', 'rating': 'PG - Children'},
#  'genres': ['Kids', 'Fantasy', 'Comedy'],
#  'main_title': 'Kerokko Demetan',
#  'other_titles': ['Adventures On Rainbow Pond',
#                   'Demetan Croaker, The Boy Frog, The Brave Frog, The Brave '
#                   "Frog's Greatest Adventure",
#                   'けろっこデメタン'],
#  'producers': {'Tatsunoko Production'},
#  'ranked_popularity': {'popularity': '10426', 'rank': '8072'},
#  'related_anime': None,
#  'score': '6.01',
#  'synopsis': 'Demetan comes from such a poor family that he cannot even go to '
#              'school in his woodland pond community. However, he has a friend '
#              'named Ranatan, the lovely, gentle frog girl who is the daughter '
#              "of the pond's rich ruler. Naturally her father is quite "
#              'displeased by this relationship and he seeks to break it up. '
#              'Nevertheless the young frogs continue with courage and '
#              'confidence, not only to live their own lives but to guide the '
#              'heartless leopard frog to a sense of justice and generosity. '
#              'Gradually the pond community responds to their sincerity and '
#              'joins them in a march toward a bright future. '}
# 2020-12-11 23:39:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/5290/Keroro_Gunsou_Movie_3__Tenkuu_Daikessen_de_Arimasu> (referer: https://myanimelist.net/anime.php?letter=K&show=650)
# 2020-12-11 23:39:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/anime/5290/Keroro_Gunsou_Movie_3__Tenkuu_Daikessen_de_Arimasu>
# {'Type': 'Movie',
#  'duration_rating': {'duration': '1 hr. 35 min.', 'rating': 'PG - Children'},
#  'genres': ['Comedy', 'Sci-Fi', 'Shounen'],
#  'main_title': 'Keroro Gunsou Movie 3: Tenkuu Daikessen de Arimasu!',
#  'other_titles': ['Keroro Movie 3',
#                   'Chou Gekijouban Keroro Gunso 3: Keroro Tai Keroro - Tenkuu '
#                   'Daikessen de Arimasu!, Keroro Gunso the Super Movie 3: '
#                   'Keroro vs. Keroro Great Sky Duel de arimasu!',
#                   '超劇場版ケロロ軍曹3 ケロロ対ケロロ 天空大決戦であります！'],
#  'producers': {'Sunrise', 'Kadokawa Pictures Japan'},
#  'ranked_popularity': {'popularity': '6861', 'rank': '1710'},
#  'related_anime': {'Other': ['Keroro Gunsou: Mushakero Ohirome Sengoku Ranstar '
#                              'Dai Battle'],
#                    'Parent story': ['Keroro Gunsou']},
#  'score': '7.46',
#  'synopsis': 'The movie begins with Fuyuki Hinata and the Keroro Platoon '
#              'exploring an abandoned temple in the mountaintop city of Machu '
#              'Picchu in Peru. While on the exploration, Keroro accidentally '
#              'sets off a trap, and by chance they find a hidden chamber with a '
#              'large blue crystal in the center, on a stand that has a key in '
#              'it. Keroro leans on the key, causing the room to activate a '
#              'mysterious machine, this caused the entire temple to shake. As '
#              'soon as the group realized what was happening, they run out of '
#              'the room. While running, Keroro accidentally loses his Kero Ball '
#              'while Fuyuki catches a fleeting glimpse of a glowing young woman '
#              'as he is running out, and tells Keroro that there was a girl in '
#              'the room, but he is forced to leave the room before he can say '
#              'anything else. The group successfully escapes, while the girl '
#              '(now sprouting a pair of glowing wings) watches them leave - '
#              'while back in the chamber, something is growing within the '
#              'crystal... '}
# 2020-12-11 23:39:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/22619/Kero_Kero_Keroppi_no_Tomodachitte_Ii_na> (referer: https://myanimelist.net/anime.php?letter=K&show=650)
# 2020-12-11 23:39:52 [scrapy.extensions.logstats] INFO: Crawled 1232 pages (at 17 pages/min), scraped 1178 items (at 16 items/min)
# 2020-12-11 23:39:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/anime/22619/Kero_Kero_Keroppi_no_Tomodachitte_Ii_na>
# {'Type': 'OVA',
#  'duration_rating': {'duration': '30 min.', 'rating': 'G - All Ages'},
#  'genres': ['Kids'],
#  'main_title': 'Kero Kero Keroppi no Tomodachitte Ii na',
#  'other_titles': ["Hello Kitty and Friends: Let's Be Friends, Keroppi and "
#                   "Friends: Let's Be Friends",
#                   'けろけろけろっぴの友だちっていいな'],
#  'producers': {'Sanrio'},
#  'ranked_popularity': {'popularity': '14606', 'rank': '14792'},
#  'related_anime': None,
#  'score': 'N/A',
#  'synopsis': "A new kid moves to town for a short stay with his father. He's "
#              'really good at playing the ocarina but difficult to befriend. A '
#              'bird likes to listen to his music and when a storm arrives they '
#              'all help the bird by placing it and its nest into a bird house; '
#              'this helps them all form an everlasting friendship as he moves '
#              'once again.'}
# 2020-12-11 23:39:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/7451/Kids_Castle> (referer: https://myanimelist.net/anime.php?letter=K&show=650)
# 2020-12-11 23:39:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/anime/7451/Kids_Castle>
# {'Type': 'Movie',
#  'duration_rating': {'duration': '4 min.', 'rating': 'G - All Ages'},
#  'genres': ['Comedy'],
#  'main_title': "Kid's Castle",
#  'other_titles': ["Kid's Castle", 'キッズキャッスル'],
#  'producers': {'Yamamura Animation, Inc.'},
#  'ranked_popularity': {'popularity': '11329', 'rank': '9759'},
#  'related_anime': None,
#  'score': '5.40',
#  'synopsis': "Take a journey into the imaginative world of Kid's Caste where a "
#              "young boy's dreams make playing with toys a reality. As his room "
#              'takes on exciting changes, you, too, will delight at the many '
#              'different whimsical sounds and voices.'}
# 2020-12-11 23:40:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/2408/Keroro_Gunsou_Movie_2__Shinkai_no_Princess_de_Arimasu> (referer: https://myanimelist.net/anime.php?letter=K&show=650)
# 2020-12-11 23:40:00 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/anime/2408/Keroro_Gunsou_Movie_2__Shinkai_no_Princess_de_Arimasu>
# {'Type': 'Movie',
#  'duration_rating': {'duration': '1 hr. 18 min.', 'rating': 'PG - Children'},
#  'genres': ['Action', 'Adventure', 'Comedy', 'Drama', 'Sci-Fi', 'Shounen'],
#  'main_title': 'Keroro Gunsou Movie 2: Shinkai no Princess de Arimasu!',
#  'other_titles': ['Sergeant Frog Movie 2',
#                   'Chou Gekijouban Keroro Gunso 2: Shinkai no Princess de '
#                   'Arimasu!, Sergeant Keroro Movie 2: The Deep Sea Princess '
#                   'Let it be so!',
#                   '超劇場版\u3000ケロロ軍曹２\u3000深海のプリンセスであります！'],
#  'producers': {'Kadokawa Shoten', 'Sunrise', 'Nihon Ad Systems'},
#  'ranked_popularity': {'popularity': '6611', 'rank': '2263'},
#  'related_anime': {'Parent story': ['Keroro Gunsou']},
#  'score': '7.32',
#  'synopsis': 'During a vacation Natsumi is visited by a female alien and male '
#              'alien who she later gains feelings for from the ocean that makes '
#              'her the Deep Sea Princess who, along with the rest of the Keroro '
#              'Platoon, encounter many dangers summoned by a mysterious '
#              'creature. '}
# 2020-12-11 23:40:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/31566/Ketsuekigata-kun_3> (referer: https://myanimelist.net/anime.php?letter=K&show=650)
# 2020-12-11 23:40:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/anime/31566/Ketsuekigata-kun_3>
# {'Type': 'TV',
#  'duration_rating': {'duration': '2 min. per ep.',
#                      'rating': 'PG-13 - Teens 13 or older'},
#  'genres': ['Comedy'],
#  'main_title': 'Ketsuekigata-kun! 3',
#  'other_titles': ['血液型くん！3'],
#  'producers': {'Assez Finaud Fabric',
#                'Earth Star Entertainment',
#                'Zexcs',
#                'feel.'},
#  'ranked_popularity': {'popularity': '7909', 'rank': '6370'},
#  'related_anime': {'Prequel': ['Ketsuekigata-kun! 2'],
#                    'Sequel': ['Ketsuekigata-kun! 4']},
#  'score': '6.39',
#  'synopsis': 'Third season of the '}
# 2020-12-11 23:40:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/17731/Ketsuekigata-kun> (referer: https://myanimelist.net/anime.php?letter=K&show=650)
# 2020-12-11 23:40:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/anime/17731/Ketsuekigata-kun>
# {'Type': 'TV',
#  'duration_rating': {'duration': '2 min. per ep.',
#                      'rating': 'PG-13 - Teens 13 or older'},
#  'genres': ['Comedy'],
#  'main_title': 'Ketsuekigata-kun!',
#  'other_titles': ['血液型くん！'],
#  'producers': {'feel.', 'Earth Star Entertainment'},
#  'ranked_popularity': {'popularity': '4923', 'rank': '5389'},
#  'related_anime': {'Sequel': ['Ketsuekigata-kun! 2']},
#  'score': '6.59',
#  'synopsis': 'The anime adapted from the manga remake version of the Korean '
#              'webtoon "A Simple Thinking about Bloodtypes" involving the '
#              'faceless and nameless characters of four different blood types '
#              'to discuss about popular anthropomorphized blood types (the '
#              'stereotypes about the blood types) in Japan and Korea.'}
# 2020-12-11 23:40:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/511/Kidou_Shinsengumi_Moeyo_Ken_TV> (referer: https://myanimelist.net/anime.php?letter=K&show=700)
# 2020-12-11 23:40:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/anime/511/Kidou_Shinsengumi_Moeyo_Ken_TV>
# {'Type': 'TV',
#  'duration_rating': {'duration': '25 min. per ep.',
#                      'rating': 'PG-13 - Teens 13 or older'},
#  'genres': ['Adventure', 'Comedy', 'Historical', 'Fantasy'],
#  'main_title': 'Kidou Shinsengumi Moeyo Ken TV',
#  'other_titles': ['Moeyo Ken TV', '機動新撰組 萌えよ剣 TV'],
#  'producers': {'ADV Films',
#                'Funimation',
#                'Picture Magic',
#                'Trinet Entertainment'},
#  'ranked_popularity': {'popularity': '6438', 'rank': '7283'},
#  'related_anime': {'Side story': ['Kidou Shinsengumi Moeyo Ken']},
#  'score': '6.20',
#  'synopsis': 'Set in an alternate version of the Meiji Era, a boy named '
#              'Sakamoto Ryunosuke returns to Kyoto from Shanghai with his '
#              'monster (youkai) Nekomaru. The law states that in order to live '
#              'freely with humans, a youkai must be liscensed. The Kidou '
#              'Shinsengumi Co. Ltd. is responsible for the capture of '
#              'unliscensed youkais but must fight with the Tsubamegumi, who '
#              'resents the new law. It turns out that Ryunosuke is the son of '
#              'the owner of the Shinsengumis.'}
# 2020-12-11 23:40:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/7843/Kiekaketa_Monogataritachi_no_Tame_ni> (referer: https://myanimelist.net/anime.php?letter=K&show=700)
# 2020-12-11 23:40:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/anime/7843/Kiekaketa_Monogataritachi_no_Tame_ni>
# {'Type': 'Movie',
#  'duration_rating': {'duration': '9 min.', 'rating': 'R+ - Mild Nudity'},
#  'genres': ['Dementia'],
#  'main_title': 'Kiekaketa Monogataritachi no Tame ni',
#  'other_titles': ['For Almost Forgotten Stories',
#                   'Kiekaketa Monogatari-tachi no Tame ni',
#                   '消えかけた物語たちの為に'],
#  'producers': [],
#  'ranked_popularity': {'popularity': '10685', 'rank': '10388'},
#  'related_anime': None,
#  'score': '5.00',
#  'synopsis': 'A somewhat dark and surreal tale by Naoyuki Tsuji. Our '
#              'protagonist sets out on a journey in a world which starts at The '
#              'Gate of Confusion. To complete his travels, he must meet various '
#              'strange characters to relieve himself of his burdens and set '
#              'himself free.'}
# 2020-12-11 23:40:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/17981/Kiki_to_Lala_no_Hoshi_no_Dance_Shoes> (referer: https://myanimelist.net/anime.php?letter=K&show=700)
# 2020-12-11 23:40:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/anime/17981/Kiki_to_Lala_no_Hoshi_no_Dance_Shoes>
# {'Type': 'OVA',
#  'duration_rating': {'duration': '30 min.', 'rating': 'G - All Ages'},
#  'genres': ['Kids', 'Music'],
#  'main_title': 'Kiki to Lala no Hoshi no Dance Shoes',
#  'other_titles': ['キキとララの星のダンスシューズ'],
#  'producers': {'Sanrio'},
#  'ranked_popularity': {'popularity': '14025', 'rank': '14817'},
#  'related_anime': {'Other': ['Kiki to Lala no Aoi Tori',
#                              'Kiki to Lala no Hansel to Gretel',
#                              'Kiki to Lala no Ohimesama ni Naritai',
#                              'Kiki to Lala no Hakuchouza no Ohimesama',
#                              'Kiki to Lala no Papa to Mama ni Aitai']},
#  'score': 'N/A',
#  'synopsis': "It's dancing time for Kiki and Lala."}
# 2020-12-11 23:40:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/17483/Kiki_to_Lala_no_Hansel_to_Gretel> (referer: https://myanimelist.net/anime.php?letter=K&show=700)
# 2020-12-11 23:40:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/anime/17483/Kiki_to_Lala_no_Hansel_to_Gretel>
# {'Type': 'OVA',
#  'duration_rating': {'duration': '28 min.', 'rating': 'G - All Ages'},
#  'genres': ['Kids', 'Fantasy'],
#  'main_title': 'Kiki to Lala no Hansel to Gretel',
#  'other_titles': ['キキとララのヘンゼルとグレーテル'],
#  'producers': {'Sanrio'},
#  'ranked_popularity': {'popularity': '14533', 'rank': '14816'},
#  'related_anime': {'Other': ['Kiki to Lala no Aoi Tori',
#                              'Kiki to Lala no Hansel to Gretel',
#                              'Kiki to Lala no Ohimesama ni Naritai',
#                              'Kiki to Lala no Hakuchouza no Ohimesama',
#                              'Kiki to Lala no Papa to Mama ni Aitai',
#                              'Kiki to Lala no Hoshi no Dance Shoes']},
#  'score': 'N/A',
#  'synopsis': "A continuation of Kiki and Lala's adventures. Loosely based on "
#              'the fairy tale '}
# ^C
# 2020-12-11 23:40:21 [scrapy.crawler] INFO: Received SIGINT, shutting down gracefully. Send again to force
# 2020-12-11 23:40:21 [scrapy.core.engine] INFO: Closing spider (shutdown)
